# %%
import os
import xarray as xr
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
data_dir = '/Users/chloecheng/Documents/Stanford-SEA/bgc_argo/data'

def get_file_paths(data_dir, filenames):
    return [os.path.join(data_dir, filename) for filename in filenames]

filenames = sorted(os.listdir(data_dir))
for f in filenames:
    if f[0] == '.':
        filenames.remove(f)



file_paths = get_file_paths(data_dir, filenames)
dataset = concatenate_files(file_paths)

file_paths
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 17
#      14     return combined_dataset
#      16 file_paths = get_file_paths(data_dir, filenames)
# ---> 17 dataset = concatenate_files(file_paths)
#      19 file_paths
#
# Cell In[7], line 13, in concatenate_files(file_paths)
#      11 def concatenate_files(file_paths):
#      12     datasets = [xr.open_dataset(file) for file in file_paths]
# ---> 13     combined_dataset = xr.concat(datasets, dim='JULD')
#      14     return combined_dataset
#
# File ~/opt/anaconda3/envs/island/lib/python3.12/site-packages/xarray/core/concat.py:252, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     240     return _dataarray_concat(
#     241         objs,
#     242         dim=dim,
#    (...)
#     249         combine_attrs=combine_attrs,
#     250     )
# ...

# %%
import matplotlib.pyplot as plt
ds = xr.open_dataset('/Users/chloecheng/Downloads/BR6902909_001D.nc').CHLA[3]
plt.plot(ds)
